# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN
# Out:
# /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN/.git/

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   gitcommands.ipynb

# %%
# !git config --global user.email "ayushverma8900@gmail.com"
# !git config --global user.name "code1ayush"

# %%
# !git commit -m "Feature extraction Model"
# Out:
# [main 9bd9529] Feature extraction Model
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git branch -M main

# %%
# !git remote add origin https://github.com/code1ayush/Food_Classifier_CNN.git
# Out:
# error: remote origin already exists.
# origin	https://github.com/code1ayush/Food_Classifier_CNN.git (fetch)
# origin	https://github.com/code1ayush/Food_Classifier_CNN.git (push)

# %%
# !git remote -v
# Out:
# origin	https://github.com/code1ayush/Food_Classifier_CNN.git (fetch)
# origin	https://github.com/code1ayush/Food_Classifier_CNN.git (push)

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global --get user.email
# !git config --global --get user.name
# Out:
# ayushverma8900@gmail.com
# code1ayush

# %%
# !git remote -v
# Out:
# origin	https://github.com/code1ayush/Food_Classifier_CNN.git (fetch)
# origin	https://github.com/code1ayush/Food_Classifier_CNN.git (push)

# %%
https://github.com/code1ayush/Food_Classifier_CNN.git
