# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN
# Out:
# /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN

# %%
# !git config --global user.name "code1ayush"
# !git config --global user.email "ayushverma8900@gmail.com"

# %%
# !git config --global --get user.email
# !git config --global --get user.name
# Out:
# ayushverma8900@gmail.com
# code1ayush

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN/.git/
