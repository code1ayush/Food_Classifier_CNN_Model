# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN
# Out:
# /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN

# %%
# !git config --global user.name "code1ayush"
# !git config --global user.email "ayushverma8900@gmail.com"

# %%
# !git config --global --get user.email
# !git config --global --get user.name
# Out:
# ayushverma8900@gmail.com
# code1ayush

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/Food_Classifier_CNN/.git/

# %%
# !git add .

# %%
# !git commit -m "feature extraction model"
# Out:
# [main a2b7dcc] feature extraction model
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite gitcommand.ipynb (97%)

# %%
# !git branch -M main

# %%
# !git remote set-url origin https://github.com/code1ayush/Food_Classifier_CNN_Model.git

# %%
# !git remote -v
# Out:
# origin	https://github.com/code1ayush/Food_Classifier_CNN_Model.git (fetch)
# origin	https://github.com/code1ayush/Food_Classifier_CNN_Model.git (push)

# %%
# !git push -u origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote set-url origin git@github.com:code1ayush/Food_Classifier_CNN_Model.git

# %%
# !git credential-cache exit

# %%
# !git push -u origin main
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git push https://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@github.com/code1ayush/Food_Classifier_CNN_Model.git
# Out:
# Enumerating objects: 27, done.
# Counting objects: 100% (27/27), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (27/27), done.
# Writing objects: 100% (27/27), 16.15 MiB | 2.94 MiB/s, done.
# Total 27 (delta 13), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (13/13), done.
# To https://github.com/code1ayush/Food_Classifier_CNN_Model.git
#  * [new branch]      main -> main
